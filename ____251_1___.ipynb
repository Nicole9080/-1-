# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicole9080/-1-/blob/main/____251_1___.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
from typing import Any, Optional

class StackWithQueues:
    def __init__(self):
        self.queue1 = deque()  # Основная очередь
        self.queue2 = deque()  # Вспомогательная очередь

    def push(self, item: Any) -> None:

        self.queue2.append(item)


        while self.queue1:
            self.queue2.append(self.queue1.popleft())


        self.queue1, self.queue2 = self.queue2, self.queue1

    def pop(self) -> Optional[Any]:
        if not self.queue1:
            raise IndexError("Стек пуст")
        return self.queue1.popleft()

    def peek(self) -> Optional[Any]:
        if not self.queue1:
            raise IndexError("Стек пуст")
        return self.queue1[0]

# %%
def test_stack():
    stack = StackWithQueues()

    try:
        print("Тестирование стека:")

        stack.push(1)
        stack.push(2)
        stack.push(3)

        print(f"Удален элемент: {stack.pop()}")  # 3
        print(f"Удален элемент: {stack.pop()}")  # 2

    except IndexError as e:
        print(f"Ошибка: {e}")

test_stack()
# Out:
# Тестирование стека:
# Удален элемент: 3
# Удален элемент: 2
